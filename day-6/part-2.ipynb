# %%
with open('file.in') as f:
    data = f.read()

# %%
data
# Out:
# '...'

# %%
buffer = []
packet_len = 14
for i, c in enumerate(data):
    print(buffer)
    while len(buffer) < packet_len:
        buffer.append(c)
    
    if len(set(buffer)) == len(buffer) and len(buffer) == packet_len:
        first_char = i
        break
    else:
        del buffer[0]
        buffer.append(c)
# Out:
# []
# ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p']
# ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'n']
# ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'n', 'n']
# ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'n', 'n', 'f']
# ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'n', 'n', 'f', 'h']
# ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'n', 'n', 'f', 'h', 'n']
# ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'n', 'n', 'f', 'h', 'n', 'h']
# ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'n', 'n', 'f', 'h', 'n', 'h', 's']
# ['p', 'p', 'p', 'p', 'p', 'p', 'n', 'n', 'f', 'h', 'n', 'h', 's', 'h']
# ['p', 'p', 'p', 'p', 'p', 'n', 'n', 'f', 'h', 'n', 'h', 's', 'h', 'r']
# ['p', 'p', 'p', 'p', 'n', 'n', 'f', 'h', 'n', 'h', 's', 'h', 'r', 'h']
# ['p', 'p', 'p', 'n', 'n', 'f', 'h', 'n', 'h', 's', 'h', 'r', 'h', 'm']
# ['p', 'p', 'n', 'n', 'f', 'h', 'n', 'h', 's', 'h', 'r', 'h', 'm', 'h']
# ...

# %%
first_char
# Out:
# 3774
